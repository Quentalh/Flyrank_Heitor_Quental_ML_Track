# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# **Lane:** Freestyle
#
# **My Question:**
# My question seeks to identify what observable content patterns are associated with pages that capture a disproportionately high percentage of AI-referred click-throughs compared to traditional organic search sessions.
#
# **Why this one:**
# I chose it because answering it can provide insight into which pages are more likely to capture AI referrals and how these referrals differ from traditional organic search sessions. Both represent extremely useful information for better understanding the landscape FlyRank is operating in during the AI era, enabeling it to provide better and more reliable services.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# **Decision:**
# My work helps prioritize which existing pages the content team should review and update first to capture emerging AI-referred traffic.
#
# **Action:**
# A content editor or SEO specialist updates the page structure based on the patterns identified.
#
# **Cost of a wrong call:**
# Wasted editorial hours optimizing pages that have no real potential for AI referrals, while missing out on pages that are perfectly positioned to capture that new traffic.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os, sys, subprocess
import pandas as pd

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
elif os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")  # move from notebooks/ to the repo root

print("Working dir:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "starter CSV not found — are you at the repo root?"
print("Starter data found. You're ready.")


df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
total_pages = len(df)
ai_traffic_pages = len(df[df['ai_traffic_pct'] > 0])
ai_traffic_max = df['ai_traffic_pct'].max()

print(f"Total pages in the sample: {total_pages}")
print(f"Pages capturing at least some AI-referred traffic: {ai_traffic_pages}")
print(f"Maximum AI traffic percentage captured by a single page: {ai_traffic_max}%")
# Out:
# Working dir: /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter
# Starter data found. You're ready.
# Total pages in the sample: 30000
# Pages capturing at least some AI-referred traffic: 1930
# Maximum AI traffic percentage captured by a single page: 300.0%

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# **What my work will be able to say:**
# My findings will be observational and directional. I will be able to say that certain content structures are "associated with" or "correlated with" higher AI-referred click-throughs. This acts as support to help content teams prioritize which pages are worth reviewing first.
#
# **What my work will never say:**
# I will never claim to have proved Google's algorithm or reverse-engineered any AI platform. Furthermore, I cannot claim causal proof, meaning I cannot guarantee that editing a page's structure will definitively cause a surge in AI traffic.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
